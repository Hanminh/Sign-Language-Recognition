# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from Modules import *
from Generate_Data.data_augmentation import *
import data_loader
import os
import torch
from Modules import BiLSTM
from Modules.BiLSTM import BiLSTM
from Modules.correlationNet import ResNet, BasicBlock
from slr_network import SLR_Network
from torch.nn import CTCLoss
from argument import *
import gc
from tqdm import tqdm

# %%
# "C:\Users\minhh\Downloads\CorrNet_Checkpoint"

root = "C:\\Users\\minhh\\Downloads\\CorrNet_Checkpoint"
loss = []
for path in os.listdir(root):
    checkpoint = torch.load(os.path.join(root, path))
    loss.append(checkpoint['loss'])
    print(checkpoint['loss'])
# Out:
# 25.52493370271665
# 29.097912459305604
# 27.51707129802013
# 26.526551631234142
# 34.396080189108375
# 33.33484921959705
# 30.708488026736756
# 37.60403582779218
# 28.111801061980856
# 35.38927804869353

# %%
import matplotlib.pyplot as plt
plt.plot(loss)
plt.show()
